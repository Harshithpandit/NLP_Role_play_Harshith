# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0820ef79-94fb-4e9a-a1a0-923cce099992" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0820ef79-94fb-4e9a-a1a0-923cce099992">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df.head()
# Out:
#    Class Index                                              Title  \
# 0            3  Wall St. Bears Claw Back Into the Black (Reuters)
# 1            3  Carlyle Looks Toward Commercial Aerospace (Reu...
# 2            3    Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3            3  Iraq Halts Oil Exports from Main Southern Pipe...
# 4            3  Oil prices soar to all-time record, posing new...
#
#                                          Description
# 0  Reuters - Short-sellers, Wall Street's dwindli...
# 1  Reuters - Private investment firm Carlyle Grou...
# 2  Reuters - Soaring crude prices plus worries\ab...
# 3  Reuters - Authorities have halted oil export\f...
# 4  AFP - Tearaway world oil prices, toppling reco...

# %%
train_df['text'] = train_df['Title'] + " " + train_df['Description']

test_df['text'] = test_df['Title'] + " " + test_df['Description']

# %%
train_df.head()
# Out:
#    Class Index                                              Title  \
# 0            3  Wall St. Bears Claw Back Into the Black (Reuters)
# 1            3  Carlyle Looks Toward Commercial Aerospace (Reu...
# 2            3    Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3            3  Iraq Halts Oil Exports from Main Southern Pipe...
# 4            3  Oil prices soar to all-time record, posing new...
#
#                                          Description  \
# 0  Reuters - Short-sellers, Wall Street's dwindli...
# 1  Reuters - Private investment firm Carlyle Grou...
# 2  Reuters - Soaring crude prices plus worries\ab...
# 3  Reuters - Authorities have halted oil export\f...
# 4  AFP - Tearaway world oil prices, toppling reco...
#
#                                                 text
# 0  Wall St. Bears Claw Back Into the Black (Reute...
# 1  Carlyle Looks Toward Commercial Aerospace (Reu...
# 2  Oil and Economy Cloud Stocks' Outlook (Reuters...
# ...

# %%
label_map = {
    1: 'World',
    2: 'Sports',
    3: 'Business',
    4: 'Sci/Tech'
}

# %%
train_df['category'] = train_df['Class Index'].map(label_map)

test_df['category'] = test_df['Class Index'].map(label_map)

# %%
train_df.tail(20)
# Out:
#         Class Index                                              Title  \
# 119980            3                    Corporate Cost-Cutters Miss Out
# 119981            3  Murdoch will shell out \$44 mil. for Manhattan...
# 119982            1  AU Says Sudan Begins Troop Withdrawal from Dar...
# 119983            1  Insurgents Attack Iraq Election Offices (Reuters)
# 119984            1  Syria Redeploys Some Security Forces in Lebano...
# 119985            1         Security Scare Closes British Airport (AP)
# 119986            1      Iraqi Judges Start Quizzing Saddam Aides (AP)
# 119987            1  Musharraf says won't quit as army chief (Reuters)
# 119988            1  Navy to go on PR 'offensive' to repair battere...
# 119989            2  NBA Wrap: Wade, O'Neal Carry Heat to 7th Strai...
# 119990            1  Barack Obama Gets  #36;1.9 Million Book Deal (AP)
# 119991            2            Rauffer Beats Favorites to Win Downhill
# ...

# %%
train_df[['Class Index', 'category']].head()
# Out:
#    Class Index  category
# 0            3  Business
# 1            3  Business
# 2            3  Business
# 3            3  Business
# 4            3  Business

# %%
import re
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
def preprocess_text(text):
  # convert text to lowercase
    text = text.lower()
     # remove special characters and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
     # tokenize text
    words = word_tokenize(text)
     # remove stopwords
    words = [word for word in words if word not in stop_words]
      # join words back
    return " ".join(words)

# %%
train_df['clean_text'] = train_df['text'].apply(preprocess_text)

test_df['clean_text'] = test_df['text'].apply(preprocess_text)

# %%
train_df[['clean_text']].head()
# Out:
#                                           clean_text
# 0  wall st bears claw back black reuters reuters ...
# 1  carlyle looks toward commercial aerospace reut...
# 2  oil economy cloud stocks outlook reuters reute...
# 3  iraq halts oil exports main southern pipeline ...
# 4  oil prices soar alltime record posing new mena...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(max_features=5000)

# %%
X_train = vectorizer.fit_transform(train_df['clean_text'])

# %%
X_test = vectorizer.transform(test_df['clean_text'])

# %%
y_train = train_df['Class Index']

y_test = test_df['Class Index']

# %%
X_train.shape
# Out:
# (120000, 5000)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9031578947368422

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.92      0.90      0.91      1900
#            2       0.94      0.98      0.96      1900
#            3       0.87      0.87      0.87      1900
#            4       0.88      0.87      0.87      1900
#
#     accuracy                           0.90      7600
#    macro avg       0.90      0.90      0.90      7600
# weighted avg       0.90      0.90      0.90      7600

# %%
def predict_news_category(text):

    # preprocess text
    cleaned_text = preprocess_text(text)

    # convert to tf-idf vector
    vectorized_text = vectorizer.transform([cleaned_text])

    # predict category
    prediction = model.predict(vectorized_text)[0]

    # map label to category
    label_map = {
        1: 'World',
        2: 'Sports',
        3: 'Business',
        4: 'Sci/Tech'
    }

    return label_map[prediction]

# %%
sample_news = """
Apple launches new AI-powered iPhone chip with advanced machine learning capabilities.
"""

print(predict_news_category(sample_news))
# Out:
# Sci/Tech

# %%
sample_news = """
India defeated Australia in the cricket world cup final after a brilliant batting performance.
"""
print(predict_news_category(sample_news))
# Out:
# Sports

# %%
sample_news = """
Global stock markets fell sharply as inflation concerns impacted investor confidence.
"""
print(predict_news_category(sample_news))
# Out:
# Business

# %%
sample_news = """
Normally clannish and agressive Argentine ants have become so laid back since arriving in Australia decades ago that they no longer fight neighboring nests and have formed a supercolony here that spans 60 miles, scientists say."""
print(predict_news_category(sample_news))
# Out:
# Sci/Tech

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 122.4 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from collections import Counter
from string import punctuation

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = """
India defeated Australia in the cricket world cup final after a brilliant batting performance.

Virat Kohli scored a magnificent century and led the team to victory.

Fans celebrated across the country after the historic win.

Experts called it one of the greatest cricket finals ever played.
"""

# %%
doc = nlp(text)

# %%
for sent in doc.sents:
    print(sent)
# Out:
# India defeated Australia in the cricket world cup final after a brilliant batting performance.
#
#
# Virat Kohli scored a magnificent century and led the team to victory.
#
#
# Fans celebrated across the country after the historic win.
#
#
# Experts called it one of the greatest cricket finals ever played.

# %%
stop_words = list(spacy.lang.en.stop_words.STOP_WORDS)

# %%
word_frequencies = {}

for word in doc:

    if (
        word.text.lower() not in stop_words
        and word.text.lower() not in punctuation
        and word.text.strip() != ""
    ):

        if word.text.lower() not in word_frequencies:
            word_frequencies[word.text.lower()] = 1

        else:
            word_frequencies[word.text.lower()] += 1

# %%
print(word_frequencies)
# Out:
# {'india': 1, 'defeated': 1, 'australia': 1, 'cricket': 2, 'world': 1, 'cup': 1, 'final': 1, 'brilliant': 1, 'batting': 1, 'performance': 1, 'virat': 1, 'kohli': 1, 'scored': 1, 'magnificent': 1, 'century': 1, 'led': 1, 'team': 1, 'victory': 1, 'fans': 1, 'celebrated': 1, 'country': 1, 'historic': 1, 'win': 1, 'experts': 1, 'called': 1, 'greatest': 1, 'finals': 1, 'played': 1}

# %%
max_frequency = max(word_frequencies.values())

# %%
for word in word_frequencies.keys():
    word_frequencies[word] = (
        word_frequencies[word] / max_frequency
    )

# %%
print(word_frequencies)
# Out:
# {'india': 0.5, 'defeated': 0.5, 'australia': 0.5, 'cricket': 1.0, 'world': 0.5, 'cup': 0.5, 'final': 0.5, 'brilliant': 0.5, 'batting': 0.5, 'performance': 0.5, 'virat': 0.5, 'kohli': 0.5, 'scored': 0.5, 'magnificent': 0.5, 'century': 0.5, 'led': 0.5, 'team': 0.5, 'victory': 0.5, 'fans': 0.5, 'celebrated': 0.5, 'country': 0.5, 'historic': 0.5, 'win': 0.5, 'experts': 0.5, 'called': 0.5, 'greatest': 0.5, 'finals': 0.5, 'played': 0.5}

# %%
sentence_scores = {}

for sent in doc.sents:

    for word in sent:

        if word.text.lower() in word_frequencies:

            if sent not in sentence_scores:
                sentence_scores[sent] = word_frequencies[word.text.lower()]

            else:
                sentence_scores[sent] += word_frequencies[word.text.lower()]

# %%
print(sentence_scores)
# Out:
# {
# India defeated Australia in the cricket world cup final after a brilliant batting performance.
#
# : 5.5, Virat Kohli scored a magnificent century and led the team to victory.
#
# : 4.0, Fans celebrated across the country after the historic win.
#
# : 2.5, Experts called it one of the greatest cricket finals ever played.
# : 3.5}

# %%
import joblib

joblib.dump(model, "news_classifier_model.pkl")

joblib.dump(vectorizer, "tfidf_vectorizer.pkl")
# Out:
# ['tfidf_vectorizer.pkl']

# %%
# %%writefile app.py

import streamlit as st

st.title("Hello")
# Out:
# Writing app.py

# %%
# !ls
# Out:
# app.py			   sample_data	tfidf_vectorizer.pkl
# news_classifier_model.pkl  test.csv	train.csv

# %%
# !pip install streamlit pyngrok
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 66.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 91.3 MB/s eta 0:00:00
# ...

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !ngrok config add-authtoken 3DfwdnbuWovah2i0IZ7DUCHOgTR_2kmtoj73MHHozo8kXLFM6
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501)

print(public_url)
# Out:
# NgrokTunnel: "https://embroider-eligible-overwrite.ngrok-free.dev" -> "http://localhost:8501"

# %%
# %%writefile app.py
# Out:
# Overwriting app.py

# %%
# %%writefile app.py

import streamlit as st
import joblib
import re
import spacy

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from string import punctuation
from heapq import nlargest

# load spacy model
nlp = spacy.load("en_core_web_sm")

# load trained model and vectorizer
model = joblib.load("news_classifier_model.pkl")
vectorizer = joblib.load("tfidf_vectorizer.pkl")

# stopwords
stop_words = set(stopwords.words('english'))

# preprocessing function
def preprocess_text(text):

    text = text.lower()

    text = re.sub(r'[^a-zA-Z\s]', '', text)

    words = word_tokenize(text)

    words = [word for word in words if word not in stop_words]

    return " ".join(words)

# prediction function
def predict_news_category(text):

    cleaned_text = preprocess_text(text)

    vectorized_text = vectorizer.transform([cleaned_text])

    prediction = model.predict(vectorized_text)[0]

    label_map = {
        1: 'World',
        2: 'Sports',
        3: 'Business',
        4: 'Sci/Tech'
    }

    return label_map[prediction]

# summarization function
def summarize_text(text):

    doc = nlp(text)

    word_frequencies = {}

    for word in doc:

        if (
            word.text.lower() not in stop_words
            and word.text.lower() not in punctuation
            and word.text.strip() != ""
        ):

            if word.text.lower() not in word_frequencies:
                word_frequencies[word.text.lower()] = 1

            else:
                word_frequencies[word.text.lower()] += 1

    max_frequency = max(word_frequencies.values())

    for word in word_frequencies.keys():
        word_frequencies[word] = (
            word_frequencies[word] / max_frequency
        )

    sentence_scores = {}

    for sent in doc.sents:

        for word in sent:

            if word.text.lower() in word_frequencies:

                if sent not in sentence_scores:
                    sentence_scores[sent] = word_frequencies[word.text.lower()]

                else:
                    sentence_scores[sent] += word_frequencies[word.text.lower()]

    summary_sentences = nlargest(
        2,
        sentence_scores,
        key=sentence_scores.get
    )

    final_summary = " ".join(
        [sent.text for sent in summary_sentences]
    )

    return final_summary

# streamlit UI
st.title("Smart News Classification & Summarization")

st.write("Paste a news article below to classify and summarize it.")

user_input = st.text_area("Enter News Article")

if st.button("Analyze Article"):

    if user_input.strip() != "":

        category = predict_news_category(user_input)

        summary = summarize_text(user_input)

        st.subheader("Predicted Category")
        st.success(category)

        st.subheader("Article Summary")
        st.write(summary)

    else:

        st.warning("Please enter a news article.")
# Out:
# Overwriting app.py

# %%
# !pkill streamlit

# %%
# !streamlit run app.py &>/content/logs.txt &
